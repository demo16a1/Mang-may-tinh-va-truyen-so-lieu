# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import pyshark

# đương dẫn
path= r"D:/HK2_NAM3/kiemtralan2/kiemtralan2.pcapng"

# tạo đối tượng đọc file gói tin 
cap=pyshark.FileCapture(path,display_filter='http.request')

print("Phân tích gói http request chứa từ khóa 'login' hoặc 'test'\n")

# duyệt qua từng gói tin trong file
for i, pkt in enumerate(cap):
    try:
        # chuyển toàn bộ nội dung http sang dạng chữ thường để tìm kiếm dễ hơn
        http_info=str(pkt.http).lower()

        # nếu trong nội dung chứa "login" hoặc"test"
        if "login" in http_info or "test" in http_info:
            print('='*50)
            print(f"Gói # {i+1} có chưa từ khóa")

            # hiển thị thời gian bắt đc gói tin
            print("Thời gian:",pkt.sniff_time)

            # hiển thị Ip nguồn và IP đích (máy chủ)
            print("IP nguồn: ",pkt.ip.src if hasattr(pkt,'ip')else "N/A")
            print("IP đích: ",pkt.ip.dst if hasattr(pkt,'ip')else "N/A")

            # hiển thị phương thức http :get hoặc post
            if hasattr (pkt.http,'request_method'):
                print("Phương thức :",pkt.http.request_method)

            # hiển thị url đầy đủ nếu có
            if hasattr(pkt.http,"host")and hasattr(pkt.http,"request_uri"):
                print("URL:",f"http://{pkt.http.host}{pkt.http.request_uri}")

            # hiển thị cookie nếu gói có gửi cookie
            if hasattr(pkt.http,"cookie"):
                print("Cookie:",pkt.http.cookie)

            # hiển thị dữ liệu gửi đi trong phần thân(post form data)
            if hasattr(pkt.http,"file_data"):
                print("Payload",pkt.http.file_data)

    # nếu có lỗi 
    except Exception as e:
        print(f"[Lỗi tại gói# {i+1}]:{e}")
# Out:
# Phân tích gói http request chứa từ khóa 'login' hoặc 'test'
#
# [Lỗi tại gói# 1]:No attribute named http
# [Lỗi tại gói# 2]:No attribute named http
# ==================================================
# Gói # 3 có chưa từ khóa
# Thời gian: 2025-04-09 08:33:17.129679
# IP nguồn:  172.31.35.87
# IP đích:  44.228.249.3
# Phương thức : POST
# URL: http://testphp.vulnweb.com/userinfo.php
# Cookie: login=test%2Ftest
# Payload 75:72:6e:61:6d:65:3d:61:64:6d:69:6e:26:75:63:63:3d:31:32:33:34:2d:35:36:37:38:2d:32:33:30:30:2d:39:30:30:30:26:75:65:6d:61:69:6c:3d:65:6d:61:69:6c:25:34:30:65:6d:61:69:6c:2e:63:6f:6d:26:75:70:68:6f:6e:65:3d:32:33:32:33:33:34:35:26:75:61:64:64:72:65:73:73:3d:32:31:2b:73:74:72:65:65:74:26:75:70:64:61:74:65:3d:75:70:64:61:74:65
# [Lỗi tại gói# 6]:No attribute named http
# [Lỗi tại gói# 7]:No attribute named http
# [Lỗi tại gói# 8]:No attribute named http
# [Lỗi tại gói# 9]:No attribute named http
# [Lỗi tại gói# 10]:No attribute named http
# [Lỗi tại gói# 11]:No attribute named http
# [Lỗi tại gói# 12]:No attribute named http
# ==================================================
# Gói # 13 có chưa từ khóa
# Thời gian: 2025-04-09 08:33:33.621215
# IP nguồn:  172.31.35.87
# IP đích:  44.228.249.3
# Phương thức : POST
# URL: http://testphp.vulnweb.com/userinfo.php
# Cookie: login=test%2Ftest
# Payload 75:72:6e:61:6d:65:3d:61:64:6d:69:6e:26:75:63:63:3d:31:32:33:34:2d:35:36:37:38:2d:32:33:30:30:2d:39:30:30:30:26:75:65:6d:61:69:6c:3d:65:6d:61:69:6c:25:34:30:65:6d:61:69:6c:2e:63:6f:6d:26:75:70:68:6f:6e:65:3d:32:33:32:33:33:34:35:26:75:61:64:64:72:65:73:73:3d:32:31:2b:73:74:72:65:65:74:26:75:70:64:61:74:65:3d:75:70:64:61:74:65
# [Lỗi tại gói# 14]:No attribute named http
# [Lỗi tại gói# 15]:No attribute named http
# [Lỗi tại gói# 16]:No attribute named http
# [Lỗi tại gói# 17]:No attribute named http
# [Lỗi tại gói# 18]:No attribute named http
# [Lỗi tại gói# 20]:No attribute named http
# [Lỗi tại gói# 21]:No attribute named http
# [Lỗi tại gói# 22]:No attribute named http
# [Lỗi tại gói# 23]:No attribute named http
# [Lỗi tại gói# 24]:No attribute named http
# [Lỗi tại gói# 25]:No attribute named http
# [Lỗi tại gói# 26]:No attribute named http
# [Lỗi tại gói# 27]:No attribute named http
# [Lỗi tại gói# 28]:No attribute named http
# [Lỗi tại gói# 29]:No attribute named http
# [Lỗi tại gói# 30]:No attribute named http
# [Lỗi tại gói# 31]:No attribute named http
# [Lỗi tại gói# 32]:No attribute named http
# [Lỗi tại gói# 33]:No attribute named http
# [Lỗi tại gói# 34]:No attribute named http
# [Lỗi tại gói# 35]:No attribute named http
# [Lỗi tại gói# 36]:No attribute named http
# [Lỗi tại gói# 37]:No attribute named http
# [Lỗi tại gói# 38]:No attribute named http
# [Lỗi tại gói# 39]:No attribute named http
# [Lỗi tại gói# 40]:No attribute named http
# [Lỗi tại gói# 41]:No attribute named http
# ==================================================
# Gói # 42 có chưa từ khóa
# Thời gian: 2025-04-09 08:34:13.118300
# IP nguồn:  172.31.35.87
# IP đích:  44.228.249.3
# Phương thức : POST
# URL: http://testphp.vulnweb.com/userinfo.php
# Cookie: login=test%2Ftest
# Payload 75:72:6e:61:6d:65:3d:61:64:6d:69:6e:26:75:63:63:3d:31:32:33:34:2d:35:36:37:38:2d:32:33:30:30:2d:39:30:30:30:26:75:65:6d:61:69:6c:3d:65:6d:61:69:6c:25:34:30:65:6d:61:69:6c:2e:63:6f:6d:26:75:70:68:6f:6e:65:3d:32:33:32:33:33:34:35:26:75:61:64:64:72:65:73:73:3d:32:31:2b:73:74:72:65:65:74:26:75:70:64:61:74:65:3d:75:70:64:61:74:65
# [Lỗi tại gói# 43]:No attribute named http
# [Lỗi tại gói# 44]:No attribute named http
# ==================================================
# Gói # 45 có chưa từ khóa
# Thời gian: 2025-04-09 08:34:15.893432
# IP nguồn:  172.31.35.87
# IP đích:  44.228.249.3
# Phương thức : POST
# URL: http://testphp.vulnweb.com/userinfo.php
# Cookie: login=test%2Ftest
# Payload 75:72:6e:61:6d:65:3d:61:64:6d:69:6e:26:75:63:63:3d:31:32:33:34:2d:35:36:37:38:2d:32:33:30:30:2d:39:30:30:30:26:75:65:6d:61:69:6c:3d:65:6d:61:69:6c:25:34:30:65:6d:61:69:6c:2e:63:6f:6d:26:75:70:68:6f:6e:65:3d:32:33:32:33:33:34:35:26:75:61:64:64:72:65:73:73:3d:32:31:2b:73:74:72:65:65:74:26:75:70:64:61:74:65:3d:75:70:64:61:74:65
# [Lỗi tại gói# 46]:No attribute named http
# [Lỗi tại gói# 47]:No attribute named http
# ==================================================
# Gói # 48 có chưa từ khóa
# Thời gian: 2025-04-09 08:34:18.732020
# IP nguồn:  172.31.35.87
# IP đích:  44.228.249.3
# Phương thức : POST
# URL: http://testphp.vulnweb.com/userinfo.php
# Cookie: login=test%2Ftest
# Payload 75:72:6e:61:6d:65:3d:61:64:6d:69:6e:26:75:63:63:3d:31:32:33:34:2d:35:36:37:38:2d:32:33:30:30:2d:39:30:30:30:26:75:65:6d:61:69:6c:3d:65:6d:61:69:6c:25:34:30:65:6d:61:69:6c:2e:63:6f:6d:26:75:70:68:6f:6e:65:3d:32:33:32:33:33:34:35:26:75:61:64:64:72:65:73:73:3d:32:31:2b:73:74:72:65:65:74:26:75:70:64:61:74:65:3d:75:70:64:61:74:65
# [Lỗi tại gói# 49]:No attribute named http
# [Lỗi tại gói# 50]:No attribute named http
# [Lỗi tại gói# 51]:No attribute named http
# [Lỗi tại gói# 52]:No attribute named http
# [Lỗi tại gói# 53]:No attribute named http
# [Lỗi tại gói# 54]:No attribute named http
# [Lỗi tại gói# 55]:No attribute named http
# [Lỗi tại gói# 56]:No attribute named http
# [Lỗi tại gói# 57]:No attribute named http

# %%
for i, pkt in enumerate(cap):
    try:
        print(f"\n==== GÓI #{i+1} ====")

        # Tầng 2: Data Link (Ethernet)
        if 'eth' in pkt:
            print("Tầng 2 - MAC nguồn:", pkt.eth.src)
            print("Tầng 2 - MAC đích :", pkt.eth.dst)

        # Tầng 3: Network (IP)
        if 'ip' in pkt:
            print("Tầng 3 - IP nguồn  :", pkt.ip.src)
            print("Tầng 3 - IP đích   :", pkt.ip.dst)
            print("Tầng 3 - Giao thức :", pkt.ip.proto)

    except Exception as e:
        print(f"Lỗi tại gói #{i+1}: {e}")
    
    # Giới hạn số gói để dễ xem (tuỳ chọn)
    if i >= 10:
        break
# Out:
# ==== GÓI #1 ====
# Tầng 2 - MAC nguồn: 6a:f2:9e:49:cb:44
# Tầng 2 - MAC đích : 58:ce:2a:68:83:d7
# Tầng 3 - IP nguồn  : 172.31.36.163
# Tầng 3 - IP đích   : 239.255.255.250
# Tầng 3 - Giao thức : 17
#
# ==== GÓI #2 ====
# Tầng 2 - MAC nguồn: 00:d2:79:08:2d:35
# Tầng 2 - MAC đích : 58:ce:2a:68:83:d7
# Tầng 3 - IP nguồn  : 172.31.33.207
# Tầng 3 - IP đích   : 239.255.255.250
# Tầng 3 - Giao thức : 17
#
# ==== GÓI #3 ====
# Tầng 2 - MAC nguồn: 58:ce:2a:68:83:d7
# Tầng 2 - MAC đích : ec:c0:18:b7:18:5d
# Tầng 3 - IP nguồn  : 172.31.35.87
# Tầng 3 - IP đích   : 44.228.249.3
# Tầng 3 - Giao thức : 6
#
# ==== GÓI #4 ====
# Tầng 2 - MAC nguồn: 58:ce:2a:68:83:d7
# Tầng 2 - MAC đích : ec:c0:18:b7:18:5d
# Tầng 3 - IP nguồn  : 172.31.35.87
# Tầng 3 - IP đích   : 204.79.197.203
# Tầng 3 - Giao thức : 6
#
# ==== GÓI #5 ====
# Tầng 2 - MAC nguồn: 58:ce:2a:68:83:d7
# Tầng 2 - MAC đích : ec:c0:18:b7:18:5d
# Tầng 3 - IP nguồn  : 172.31.35.87
# Tầng 3 - IP đích   : 204.79.197.203
# Tầng 3 - Giao thức : 6
#
# ==== GÓI #6 ====
# Tầng 2 - MAC nguồn: 6a:f2:9e:49:cb:44
# Tầng 2 - MAC đích : 58:ce:2a:68:83:d7
# Tầng 3 - IP nguồn  : 172.31.36.163
# Tầng 3 - IP đích   : 239.255.255.250
# Tầng 3 - Giao thức : 17
#
# ==== GÓI #7 ====
# Tầng 2 - MAC nguồn: 6a:f2:9e:49:cb:44
# Tầng 2 - MAC đích : 58:ce:2a:68:83:d7
# Tầng 3 - IP nguồn  : 172.31.36.163
# Tầng 3 - IP đích   : 239.255.255.250
# Tầng 3 - Giao thức : 17
#
# ==== GÓI #8 ====
# Tầng 2 - MAC nguồn: 6a:f2:9e:49:cb:44
# Tầng 2 - MAC đích : 58:ce:2a:68:83:d7
# Tầng 3 - IP nguồn  : 172.31.36.163
# Tầng 3 - IP đích   : 239.255.255.250
# Tầng 3 - Giao thức : 17
#
# ==== GÓI #9 ====
# Tầng 2 - MAC nguồn: be:b2:77:3b:57:5e
# Tầng 2 - MAC đích : 58:ce:2a:68:83:d7
# Tầng 3 - IP nguồn  : 172.31.34.21
# Tầng 3 - IP đích   : 239.255.255.250
# Tầng 3 - Giao thức : 17
#
# ==== GÓI #10 ====
# Tầng 2 - MAC nguồn: 6a:f2:9e:49:cb:44
# Tầng 2 - MAC đích : 58:ce:2a:68:83:d7
# Tầng 3 - IP nguồn  : 172.31.36.163
# Tầng 3 - IP đích   : 239.255.255.250
# Tầng 3 - Giao thức : 17
#
# ==== GÓI #11 ====
# Tầng 2 - MAC nguồn: 6a:f2:9e:49:cb:44
# Tầng 2 - MAC đích : 58:ce:2a:68:83:d7
# Tầng 3 - IP nguồn  : 172.31.36.163
# Tầng 3 - IP đích   : 239.255.255.250
# Tầng 3 - Giao thức : 17
